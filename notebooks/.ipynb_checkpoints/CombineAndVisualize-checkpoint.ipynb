# %% [markdown]
# # Notebook to combine all well data for visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os

# %matplotlib inline

# %%
wells = pd.read_csv('../data/wells/well production.csv')

cumulative_productions = []

for index, row in wells.iterrows():
    cumulative_productions.append(row.values[3:15].sum())

wells['cumulative production'] = cumulative_productions
wells.head()
# Out:
#    Unnamed: 0        well name  average pressure (Pa)    oil 1    oil 2  \
# 0           0  Tarragon 4-119H               26180969  10809.0  10108.0
# 1           1   Fennel 10-129H               36433680   2049.0   1932.0
# 2           2  Federal 14-113H               36642888  11699.0  10905.0
# 3           3      King 7-184H               30429506   5980.0   5580.0
# 4           4    Sundae 1-129H               42591950   3892.0   3646.0
#
#      oil 3   oil 4   oil 5   oil 6   oil 7  ...  water 4  water 5  water 6  \
# 0   9352.0  8626.0  7856.0  7137.0  6430.0  ...   1481.0   1367.0   1237.0
# 1   1784.0  1649.0  1499.0  1364.0  1226.0  ...    210.0    205.0    200.0
# 2  10149.0  9365.0  8521.0  7732.0  6919.0  ...    661.0    617.0    541.0
# 3   5176.0  4789.0  4405.0  3978.0  3581.0  ...    471.0    453.0    417.0
# 4   3399.0  3133.0  2834.0  2577.0  2309.0  ...    974.0    902.0    806.0
#
#    water 7  water 8  water 9  water 10  water 11  water 12  \
# 0   1069.0    982.0    857.0     733.0     593.0     472.0
# 1    157.0    148.0    136.0      97.0      91.0      87.0
# 2    466.0    435.0    394.0     340.0     266.0     213.0
# 3    346.0    343.0    275.0     231.0     238.0     164.0
# 4    790.0    668.0    570.0     468.0     394.0     322.0
#
#    cumulative production
# 0                81324.0
# 1                15600.0
# 2                88023.0
# 3                45171.0
# 4                29484.0
#
# [5 rows x 28 columns]

# %%
dataframes = []
directory = '../data/wells/'

for index, row in wells.iterrows():
    well_name = row['well name']
    well = pd.read_csv(directory + well_name + '.csv')
    well['name'] = well_name
    well['cumulative production'] = row['cumulative production']
    dataframes.append(well)
        
data = pd.concat(dataframes)
data.to_csv('../data/all_wells.csv', index=False)

# %%
data.head()
# Out:
#    easting  northing  porosity  permeability  Poisson's ratio  \
# 0  66100.0   22300.0      0.09         0.033            0.332
# 1  66199.0   22300.0      0.12         0.057            0.332
# 2  66297.0   22300.0      0.11         0.050            0.332
# 3  66396.0   22300.0      0.08         0.024            0.332
# 4  66495.0   22300.0      0.08         0.031            0.332
#
#    Young's Modulus  water saturation  oil saturation  proppant weight (lbs)  \
# 0      9440769.483          0.124740        0.875260          260036.414279
# 1      9429043.880          0.124979        0.875021                    NaN
# 2      9417413.010          0.125221        0.874779          429740.754787
# 3      9405879.454          0.125469        0.874531                    NaN
# 4      9394445.773          0.125720        0.874280          485657.822229
#
#    pump rate (cubic feet/min)             name  cumulative production
# 0                  275.737593  Tarragon 4-119H                81324.0
# 1                         NaN  Tarragon 4-119H                81324.0
# 2                  324.145032  Tarragon 4-119H                81324.0
# 3                         NaN  Tarragon 4-119H                81324.0
# 4                  320.868488  Tarragon 4-119H                81324.0

# %%
def plot_feature(feature):
    plt.xlabel('easting')
    plt.ylabel('northing')
    plt.title(feature)
    plt.scatter(data['easting'], data['northing'], c=data[feature])
    plt.colorbar(label=feature)

# %% [markdown]
# Visualizing porosity

# %%
plot_feature('porosity')

# %% [markdown]
# Plotting permeability

# %%
plot_feature('permeability')

# %% [markdown]
# Plotting Poisson's ratio

# %%
plot_feature('Poisson\'s ratio')

# %% [markdown]
# Plotting Young's Modulus

# %%
plot_feature('Young\'s Modulus')

# %% [markdown]
# Plotting water saturation

# %%
plot_feature('water saturation')

# %% [markdown]
# Plotting oil saturation

# %%
plot_feature('oil saturation')
